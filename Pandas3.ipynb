# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# df.drop(),df.dropna(),df.fillna(),df.set_index(),df.reset_index()

# %% [markdown]
# ### Group by func

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.groupby("Pclass")

# %%
g=df.groupby("Pclass")
g.sum()
# Out:
# /tmp/ipykernel_577/955015598.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
g=df.groupby("Pclass")
g.sum()["Fare"]
# Out:
# /tmp/ipykernel_577/2587479000.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()["Fare"]
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6714.6951
# Name: Fare, dtype: float64

# %% [markdown]
# ### Apply func
# #### It takes Prticular col and perform fun applied on each element of that col
# #### Can work on particular row

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df["INR"]=df["Fare"].apply(lambda x : x *80)
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked       INR
# 0      0  A/5 21171   7.2500   NaN        S   580.000
# 1      0   PC 17599  71.2833   C85        C  5702.664

# %%
df["Name_len"]=df["Name"].apply(len)
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked       INR  Name_len
# 0      0  A/5 21171   7.2500   NaN        S   580.000        23
# 1      0   PC 17599  71.2833   C85        C  5702.664        51

# %%
def test (x):
    if x<15:
        return " Teen"
    elif x>=15 and x<50:
        return "Young"
    else:
        return "Old"

# %%
df["Age_grp"]=df["Age"].apply(test)
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked       INR  Name_len Age_grp
# 0      0  A/5 21171   7.2500   NaN        S   580.000        23   Young
# 1      0   PC 17599  71.2833   C85        C  5702.664        51   Young

# %%
data = {"a":[1,2,3,4],
       "b":[4,5,6,7],
       "c":["sudh" , "krish","hitesh","navin"]}
df1 = pd.DataFrame(data,index = ['a','b','c','d'])
df1
# Out:
#    a  b       c
# a  1  4    sudh
# b  2  5   krish
# c  3  6  hitesh
# d  4  7   navin

# %%
def test1 (x):
    return x.sum()

# %%
df1.apply(test1,axis=0)    # performing sum on each rows
# Out:
# a                      10
# b                      22
# c    sudhkrishhiteshnavin
# dtype: object

# %%
df1.apply(lambda x :x.sum(),axis=0)
# Out:
# a                      10
# b                      22
# c    sudhkrishhiteshnavin
# dtype: object

# %%
data = {"a":[1,2,3,4],
       "b":[4,5,6,7],
       }
df2 = pd.DataFrame(data,index = ['a','b','c','d'])
df2
# Out:
#    a  b
# a  1  4
# b  2  5
# c  3  6
# d  4  7

# %%
df2.applymap(lambda x : x **2)  #applymap map each element and perform operation
# Out:
#     a   b
# a   1  16
# b   4  25
# c   9  36
# d  16  49

# %%
pd.set_option("display.max_colwidth" ,1000)
df3 = pd.DataFrame({"Desc" :["Data Science Masters course is highly curated and uniquely designed according to the latest industry standards. This program instills students the skills essential to knowledge discovery efforts to identify standard, novel, and truly differentiated solutions and decision-making, including skills in managing, querying, analyzing, visualizing, and extracting meaning from extremely large data sets. This trending program provides students with the statistical, mathematical and computational skills needed to meet the large-scale data science challenges of today's professional world. You will learn all the stack required to work in data science industry including cloud infrastructure and real-time industry projects. This course will be taught in Hindi language." , "my name is sudh" ,"i use to teach data science "] })
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc
# ...

# %%
s= "my name is vishal"
s.split()
# Out:
# ['my', 'name', 'is', 'vishal']

# %%
len(s.split())
# Out:
# 4

# %%
df3["word count"]=df3["Desc"].apply(lambda x : len(x.split()))
df3
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Desc  \
# ...
