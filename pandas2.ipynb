# %%
import pandas as pd

# %%
type(pd)
# Out:
# module

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
a=df["Age"]
a
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
b=df["Age"][0:5]
b
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
type(a)  #series is just like list all fun of list work
# Out:
# pandas.core.series.Series

# %%
type(b)
# Out:
# pandas.core.series.Series

# %%
df[["Age"]]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
type(df[["Age"]])    # data frame fun is diff than series
# Out:
# pandas.core.frame.DataFrame

# %%
c=df[["Age","Name"]]
c
# Out:
#       Age                                               Name
# 0    22.0                            Braund, Mr. Owen Harris
# 1    38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    26.0                             Heikkinen, Miss. Laina
# 3    35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    35.0                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886  27.0                              Montvila, Rev. Juozas
# 887  19.0                       Graham, Miss. Margaret Edith
# 888   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 889  26.0                              Behr, Mr. Karl Howell
# 890  32.0                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df[["Age","Name"]][0:3]
# Out:
#     Age                                               Name
# 0  22.0                            Braund, Mr. Owen Harris
# 1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0                             Heikkinen, Miss. Laina

# %%
type(c)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[0:2]
# Out:
# PassengerId    int64
# Survived       int64
# dtype: object

# %%
df.dtypes.index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
type(df.dtypes.index)
# Out:
# pandas.core.indexes.base.Index

# %%
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
type(df.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
df.dtypes[df.dtypes==object]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
type(df.dtypes[df.dtypes==object])
# Out:
# pandas.core.series.Series

# %%
type(df.dtypes[df.dtypes==object].index)
# Out:
# pandas.core.indexes.base.Index

# %%
df[df.dtypes[df.dtypes==object].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes==object].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df[["Ticket","Cabin"]][4:11:2]
# Out:
#      Ticket Cabin
# 4    373450   NaN
# 6     17463   E46
# 8    347742   NaN
# 10  PP 9549    G6

# %%
df["new_col"]=1
df.head(3)          #created a new col
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  new_col
# 0      0         A/5 21171   7.2500   NaN        S        1
# 1      0          PC 17599  71.2833   C85        C        1
# 2      0  STON/O2. 3101282   7.9250   NaN        S        1

# %%
df["new_col"]=df["Sex"]+df["Name"]
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  \
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
#
#                                              new_col
# 0                        maleBraund, Mr. Owen Harris
# 1  femaleCumings, Mrs. John Bradley (Florence Bri...

# %%
df[4:5:1]
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
#
#    Parch  Ticket  Fare Cabin Embarked                       new_col
# 4      0  373450  8.05   NaN        S  maleAllen, Mr. William Henry

# %%
df["Age"]>=18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df[df["Age"]>=18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Age"]>=18][4:7]
# Out:
#    PassengerId  Survived  Pclass  \
# 4            5         0       3
# 6            7         0       1
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 4                           Allen, Mr. William Henry    male  35.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked  \
# 4      0  373450   8.0500   NaN        S
# 6      0   17463  51.8625   E46        S
# 8      2  347742  11.1333   NaN        S
#
#                                              new_col
# 4                       maleAllen, Mr. William Henry
# 6                        maleMcCarthy, Mr. Timothy J
# 8  femaleJohnson, Mrs. Oscar W (Elisabeth Vilhelm...

# %%
len(df[df["Age"]>=18])
# Out:
# 601

# %%
len(df[df["Age"]>=18])-100
# Out:
# 501

# %%
df.mean()
# Out:
# /tmp/ipykernel_441/3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df["Fare"]>32.204208
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df["Fare"]>32.204208]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 23            24         1       1
# 27            28         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 863          864         0       3
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Fare"]>32.204208][0:4:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch    Ticket     Fare Cabin Embarked  \
# 1      0  PC 17599  71.2833   C85        C
# 6      0     17463  51.8625   E46        S
#
#                                              new_col
# 1  femaleCumings, Mrs. John Bradley (Florence Bri...
# 6                        maleMcCarthy, Mr. Timothy J

# %%
(df["Fare"]>32.204208) &( df["Sex"]=="male")
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df[(df["Fare"]>32.204208) & (df["Sex"]=="male")]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 6              7         0       1               McCarthy, Mr. Timothy J
# 23            24         1       1          Sloper, Mr. William Thompson
# 27            28         0       1        Fortune, Mr. Charles Alexander
# 34            35         0       1               Meyer, Mr. Edgar Joseph
# 35            36         0       1        Holverson, Mr. Alexander Oskar
# ..           ...       ...     ...                                   ...
# 827          828         1       2                 Mallet, Master. Andre
# 838          839         1       3                       Chip, Mr. Chang
# 846          847         0       3              Sage, Mr. Douglas Bullen
# 848          849         0       2                     Harper, Rev. John
# 867          868         0       1  Roebling, Mr. Washington Augustus II
#
#       Sex   Age  SibSp  Parch           Ticket      Fare        Cabin  \
# ...

# %%
df[df.dtypes[df.dtypes==int].index][0:2]
# Out:
#    PassengerId  Survived  Pclass  SibSp  Parch
# 0            1         0       3      1      0
# 1            2         1       1      1      0

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  \
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
#
#                                              new_col
# 0                        maleBraund, Mr. Owen Harris
# 1  femaleCumings, Mrs. John Bradley (Florence Bri...
# 2                       femaleHeikkinen, Miss. Laina

# %%
df.loc[2:6,["Age","SibSp","Parch","Ticket","Fare","Cabin"]]  #location fun need location to navigate
# Out:
#     Age  SibSp  Parch            Ticket     Fare Cabin
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3  35.0      1      0            113803  53.1000  C123
# 4  35.0      0      0            373450   8.0500   NaN
# 5   NaN      0      0            330877   8.4583   NaN
# 6  54.0      0      0             17463  51.8625   E46

# %%
df[["Age","SibSp","Parch","Ticket","Fare","Cabin"]][2:6]
# Out:
#     Age  SibSp  Parch            Ticket     Fare Cabin
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 3  35.0      1      0            113803  53.1000  C123
# 4  35.0      0      0            373450   8.0500   NaN
# 5   NaN      0      0            330877   8.4583   NaN

# %%
s=df["Age"][0:3]
s
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# Name: Age, dtype: float64

# %%
l=["a",500,"vishal"]

# %%
p=pd.Series(list(s),index=l)   # providing my own index
p
# Out:
# a         22.0
# 500       38.0
# vishal    26.0
# dtype: float64

# %%
p[500]
# Out:
# 38.0

# %% [markdown]
# ### Different type of joins and set operstion in pandas

# %%
df2=df[["Sex","Age"]][0:5]
df2
# Out:
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
df3=df[["Name","Sex","Age"]][8:12]
df3
# Out:
#                                                  Name     Sex   Age
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0
# 11                           Bonnell, Miss. Elizabeth  female  58.0

# %%
pd.concat([df2,df3])    # pd.concat() is just like set operation sql
                        # up-down set operation
# Out:
#        Sex   Age                                               Name
# 0     male  22.0                                                NaN
# 1   female  38.0                                                NaN
# 2   female  26.0                                                NaN
# 3   female  35.0                                                NaN
# 4     male  35.0                                                NaN
# 8   female  27.0  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9   female  14.0                Nasser, Mrs. Nicholas (Adele Achem)
# 10  female   4.0                    Sandstrom, Miss. Marguerite Rut
# 11  female  58.0                           Bonnell, Miss. Elizabeth

# %%
pd.concat([df2,df3],axis=1)   # same fun is used to perform set operation up-down and sidewise also
# Out:
#        Sex   Age                                               Name     Sex  \
# 0     male  22.0                                                NaN     NaN
# 1   female  38.0                                                NaN     NaN
# 2   female  26.0                                                NaN     NaN
# 3   female  35.0                                                NaN     NaN
# 4     male  35.0                                                NaN     NaN
# 8      NaN   NaN  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9      NaN   NaN                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10     NaN   NaN                    Sandstrom, Miss. Marguerite Rut  female
# 11     NaN   NaN                           Bonnell, Miss. Elizabeth  female
#
#      Age
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 8   27.0
# 9   14.0
# 10   4.0
# 11  58.0

# %%
df4=df[["Sex","Age"]][0:5]
df4
# Out:
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
df5=df[["Name","Sex","Age"]][3:8]
df5
# Out:
#                                            Name     Sex   Age
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                      Allen, Mr. William Henry    male  35.0
# 5                              Moran, Mr. James    male   NaN
# 6                       McCarthy, Mr. Timothy J    male  54.0
# 7                Palsson, Master. Gosta Leonard    male   2.0

# %%
pd.concat([df4,df5])
# Out:
#       Sex   Age                                          Name
# 0    male  22.0                                           NaN
# 1  female  38.0                                           NaN
# 2  female  26.0                                           NaN
# 3  female  35.0                                           NaN
# 4    male  35.0                                           NaN
# 3  female  35.0  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4    male  35.0                      Allen, Mr. William Henry
# 5    male   NaN                              Moran, Mr. James
# 6    male  54.0                       McCarthy, Mr. Timothy J
# 7    male   2.0                Palsson, Master. Gosta Leonard

# %%
pd.concat([df4,df5],axis=1)
# Out:
#       Sex   Age                                          Name     Sex   Age
# 0    male  22.0                                           NaN     NaN   NaN
# 1  female  38.0                                           NaN     NaN   NaN
# 2  female  26.0                                           NaN     NaN   NaN
# 3  female  35.0  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4    male  35.0                      Allen, Mr. William Henry    male  35.0
# 5     NaN   NaN                              Moran, Mr. James    male   NaN
# 6     NaN   NaN                       McCarthy, Mr. Timothy J    male  54.0
# 7     NaN   NaN                Palsson, Master. Gosta Leonard    male   2.0

# %% [markdown]
# ### join on a particular common col like sql join operation

# %% [markdown]
# ##### pd.merge() is used

# %%
df6=pd.DataFrame({ "id":[101,102,103],
                  "Name":["vis","ashis","prash"]
                 })
df6
# Out:
#     id   Name
# 0  101    vis
# 1  102  ashis
# 2  103  prash

# %%
df7=pd.DataFrame({ "id":[101,104,105],
                  "Dpt":["mech","cse","Ai"]
                 })
df7
# Out:
#     id   Dpt
# 0  101  mech
# 1  104   cse
# 2  105    Ai

# %%
pd.merge(df6,df7 , on="id")   # perform inner join based on commmon col eg id  (foreign key)
# Out:
#     id Name   Dpt
# 0  101  vis  mech

# %%
pd.merge(df6,df7,on="id")   # same thing as above
# Out:
#     id Name   Dpt
# 0  101  vis  mech

# %%
pd.merge(df6,df7,how="left")
# Out:
#     id   Name   Dpt
# 0  101    vis  mech
# 1  102  ashis   NaN
# 2  103  prash   NaN

# %%
# pd.merge(df6,df7,on="Not_common_col_in_both_table") # will give error

# %%
df8=pd.DataFrame({ "id":[101,102,103],
                  "Name":["vis","ashis","prash"]
                 },
                 index = ["a","b","c"])
df8
# Out:
#     id   Name
# a  101    vis
# b  102  ashis
# c  103  prash

# %%
df9=pd.DataFrame({ "deptid":["d10","d85","d51"],
                  "Dept":["mech","cse","Ai"]
                 },
                 index = ["a","e","f"])
df9
# Out:
#   deptid  Dept
# a    d10  mech
# e    d85   cse
# f    d51    Ai

# %%
df8.join(df9)  # perform left join autoimatically
               # same thing like sql join but on common rows
# Out:
#     id   Name deptid  Dept
# a  101    vis    d10  mech
# b  102  ashis    NaN   NaN
# c  103  prash    NaN   NaN

# %%
df8.join(df9,how="inner")
# Out:
#     id Name deptid  Dept
# a  101  vis    d10  mech
